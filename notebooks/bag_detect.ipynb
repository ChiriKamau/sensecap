# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiriKamau/sensecap/blob/main/notebooks/bag_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install specific compiler and build tools for SenseCAP A1102
# !pip install ethos-u-vela==3.11.0
# !pip install -U openmim
# !pip install setuptools==69.5.1

# 2. Setup the repository
# !rm -rf ModelAssistant
# !git clone https://github.com/Seeed-Studio/ModelAssistant.git -b 2.0.0
# %cd ModelAssistant

# 3. Install MMLab dependencies manually to prevent version conflicts
# !mim install "mmengine>=0.7.0"
# !mim install "mmcv>=2.0.0rc4"
# !mim install "mmdet>=3.0.0"

# 4. Final SSCMA installation
# !pip install -e .
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.8/404.8 kB 13.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ethos-u-vela: filename=ethos_u_vela-3.11.0-cp312-cp312-linux_x86_64.whl size=621017 sha256=decd91a79c469cd4df36d119535b0b0306ae73b97f08e1503376a551f3abf62d
#   Stored in directory: /root/.cache/pip/wheels/18/33/4b/22a852ad66961531551b5cc668723b81e71ed504d7d39aae2f
# Successfully built ethos-u-vela
# ...
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 25.12.19
#     Uninstalling flatbuffers-25.12.19:
#       Successfully uninstalled flatbuffers-25.12.19
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from google.colab import drive
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Download pre-trained Swift-YOLO weights (Base for transfer learning)
# %mkdir -p COCO_Detection_Swift-YOLO_320
# !wget -c https://files.seeedstudio.com/sscma/model_zoo/detection/coco/swift_yolo_shuffle_coco_320_float32_sha1_a5927bd6a6c6569d27edb98da946a8e75a8d816f.pth -O COCO_Detection_Swift-YOLO_320/pretrain.pth

print("Drive mounted and pre-trained weights ready.")
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# Create the project directory
# %mkdir -p Bag_Detection_Swift-YOLO_320

# Define paths (Adjust 'MyDatasetFolder' to match your Drive folder name)
drive_path = '/content/drive/MyDrive/MyDatasetFolder'
local_path = '/content/Bag_Detection_Swift-YOLO_320/dataset'

# Create a symbolic link or copy the data
if os.path.exists(local_path):
    shutil.rmtree(local_path)

# If it's a folder:
# !ln -s "{drive_path}" "{local_path}"

# Check if the annotations exist to confirm the path is correct
print("Checking for annotations...")
# !ls {local_path}/annotations
