# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiriKamau/sensecap/blob/main/notebooks/bag_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -qq libgl1
# !pip install -q "numpy==1.26.4" --no-deps   # pin it before anything touches it
# !pip install -q mmengine
# !pip install -q git+https://github.com/Seeed-Studio/SSCMA.git

# Verify
import numpy as np, cv2, mmengine, sscma
print(f'numpy   : {np.__version__}')
print(f'opencv  : {cv2.__version__}')
print(f'mmengine: {mmengine.__version__}')
print(f'✅ SSCMA {sscma.__version__} ready')
